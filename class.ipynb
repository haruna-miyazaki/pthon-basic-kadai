# %%
class Human:
  def __init__(self, name, age):
    self.name =name
    self.age =age

  def printinfo(self):
    print("Name:",self.name)
    print("Age:",self.age)


human = Human("john", "30")

human.printinfo()
# Out:
# Name: john
# Age: 30
